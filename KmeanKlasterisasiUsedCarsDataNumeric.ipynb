# %%
#import modul
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#pembuatan dataframe
df = pd.read_csv('used_cars.csv')
df
# Out:
#           No          id                                                url  \
# 0          0  7034441763  https://saltlakecity.craigslist.org/cto/d/salt...
# 1          1  7034440610  https://saltlakecity.craigslist.org/ctd/d/sand...
# 2          2  7034440588  https://saltlakecity.craigslist.org/ctd/d/sand...
# 3          3  7034440546  https://saltlakecity.craigslist.org/ctd/d/sand...
# 4          4  7034406932  https://saltlakecity.craigslist.org/ctd/d/evan...
# 5          5  7034406582  https://saltlakecity.craigslist.org/ctd/d/evan...
# 6          6  7034405619  https://saltlakecity.craigslist.org/ctd/d/evan...
# 7          7  7034405349  https://saltlakecity.craigslist.org/ctd/d/evan...
# 8          8  7034404595  https://saltlakecity.craigslist.org/ctd/d/evan...
# 9          9  7034401857  https://saltlakecity.craigslist.org/ctd/d/evan...
# 10        10  7034401494  https://saltlakecity.craigslist.org/ctd/d/evan...
# ...

# %%
#drop column yang tidak digunakan
df.drop(['No','id','url','cylinders','region','region_url','manufacturer','model','state'],axis=1,inplace=True)
df.drop(['transmission','price','lat','long','title_status','condition','fuel','vin','drive','size','type','paint_color','image_url','description','county'],axis=1,inplace=True)

# %%
#drop NaN
df = df.dropna()
df
# Out:
#          year  odometer
# 0      2012.0   63500.0
# 1      2016.0      10.0
# 2      2015.0    7554.0
# 3      2016.0      10.0
# 4      2018.0   70150.0
# 5      2009.0  120057.0
# 6      2017.0   95484.0
# 7      2007.0   89340.0
# 8      2013.0  226031.0
# 9      2012.0  128153.0
# 10     1994.0  168838.0
# 11     2013.0  156385.0
# 12     2007.0  135287.0
# 13     2015.0   73612.0
# 14     2004.0  235790.0
# 15     2014.0  158156.0
# 16     2015.0  127515.0
# 17     2002.0  179098.0
# 18     2003.0  185220.0
# 19     2019.0   20930.0
# 20     2010.0  231570.0
# 21     2008.0   75000.0
# 24     2008.0  110982.0
# 25     2014.0   93242.0
# 27     2015.0   68013.0
# 28     2016.0   23773.0
# 29     2016.0   28000.0
# 30     1992.0   13000.0
# 32     2017.0   21125.0
# 35     2015.0   41245.0
# ...       ...       ...
# 19971  2018.0   37851.0
# 19972  2010.0  109344.0
# 19973  2006.0  128850.0
# 19974  2015.0   89644.0
# 19975  2008.0  192812.0
# 19976  2008.0   92475.0
# ...

# %%
#Informasi tipe data
df.dtypes
# Out:
# year        float64
# odometer    float64
# dtype: object

# %%
#Scalling 
from sklearn import preprocessing
import numpy as np

# %%
#Scalling data dengan min max scaller
minmaxscaler_as = preprocessing.MinMaxScaler(feature_range=(0,1))
feature_scale = minmaxscaler_as.fit_transform(df)
feature_scale
# Out:
# array([[9.22330097e-01, 2.53999492e-02],
#        [9.61165049e-01, 3.99999200e-06],
#        [9.51456311e-01, 3.02159396e-03],
#        ...,
#        [9.90291262e-01, 7.00558599e-03],
#        [9.70873786e-01, 1.21943756e-02],
#        [9.90291262e-01, 8.83118234e-03]])

# %%
#K-MEANS inisialisasi
np.random.seed(500) 
k = 3

# %%
# inisialisasi centorid
centroids = {
    i+1: [np.random.choice(df['year']), np.random.choice(df['odometer'])]
    for i in range(k)
}                        
fig = plt.figure(figsize=(5, 5))
plt.scatter(df['year'], df['odometer'], color='k')
colmap = {1: 'r', 2: 'g', 3: 'b'}
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.show()

# %%
#Pembuatan cluster dengan perhitungan centroid terdekat

def assignment(df, centroids):
    for i in centroids.keys():
        # sqrt((x1 - x2)^2 - (y1 - y2)^2)
        df['distance_from_{}'.format(i)] = (
            np.sqrt(
                (df['year'] - centroids[i][0]) ** 2
                + (df['odometer'] - centroids[i][1]) ** 2
            )
        )
    centroid_distance_cols = ['distance_from_{}'.format(i) for i in centroids.keys()]
    df['closest'] = df.loc[:, centroid_distance_cols].idxmin(axis=1)
    df['closest'] = df['closest'].map(lambda year: int(year.lstrip('distance_from_')))
    df['color'] = df['closest'].map(lambda year: colmap [year])
    return df

df = assignment(df, centroids)
print(df.head())

fig = plt.figure(figsize=(5, 5))
plt.scatter(df['year'], df['odometer'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.show()
# Out:
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#perbarui centorid menjadi rata - rata baru dan cluster baru

import copy

old_centroids = copy.deepcopy(centroids)

def update(k):
    for i in centroids.keys():
        centroids[i][0] = np.mean(df[df['closest'] == i]['year'])
        centroids[i][1] = np.mean(df[df['closest'] == i]['odometer'])
    return k

centroids = update(centroids)

fig = plt.figure(figsize=(5, 5))
ax = plt.axes()
plt.scatter(df['year'], df['odometer'], color=df['color'], alpha=0.5, edgecolor='k')

for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
    
for i in old_centroids.keys():
    old_year = old_centroids[i][0]
    old_odometer = old_centroids[i][1]
    dyear = (centroids[i][0] - old_centroids[i][0]) * 0.75
    dodometer = (centroids[i][1] - old_centroids[i][1]) * 0.75
    ax.arrow(old_year, old_odometer, dyear, dodometer, head_width=2, head_length=3, fc=colmap[i], ec=colmap[i])
plt.show()

# %%
# ulangi perbaruan centroid menjadi cluster

df = assignment(df, centroids)

fig = plt.figure(figsize=(5, 5))
plt.scatter(df['year'], df['odometer'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.show()
# Out:
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#memastikan sampai semua kategorisasi tidak berubah lagi

while True:
    closest_centroids = df['closest'].copy(deep=True)
    centroids = update(centroids)
    df = assignment(df,centroids)
    if closest_centroids.equals(df['closest']):
        break
    
fig = plt.figure(figsize=(5, 5))
plt.scatter(df['year'], df['odometer'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])

plt.show()
# Out:
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\Ghina\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
